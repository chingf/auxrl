# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import configs
import os
from scipy.stats import sem
import matplotlib.cm as cm

# %%
plt.rcParams['font.family'] = 'sans-serif'

# %% [markdown]
# # Gridworld

# %%
# %matplotlib inline

# %%
from auxrl.environments import AlternatingT as env

# %%
env = Env(8)

# %%
env.plot_state()

# %% [markdown]
# # Figure 8 Noise

# %%
#from deer.environments.FourRoom import MyEnv as Env
from deer.environments.Figure8 import MyEnv as Env

# %%
x = Env(higher_dim_obs=True, show_rewards=False, give_rewards=True, obs_noise=1.)

# %%
m = x.observe()[0]

# %%
m.max()
# Out:
# 4.606097180085584

# %%
# %matplotlib notebook
plt.figure()
plt.imshow(m)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
plt.figure()
plt.imshow(m + np.random.normal(0,0.2, size=m.shape))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
m
# Out:
# array([[ 2.,  2.,  2.,  2.,  2.,  2.],
#        [ 2.,  0.,  0.,  0.,  0.,  2.],
#        [ 2.,  0., -1., -1.,  0.,  2.],
#        [ 2., 10.,  0.,  0.,  0.,  2.],
#        [ 2.,  0., -1., -1.,  0.,  2.],
#        [ 2.,  0.,  0.,  0.,  0.,  2.],
#        [ 2.,  2.,  2.,  2.,  2.,  2.]])
