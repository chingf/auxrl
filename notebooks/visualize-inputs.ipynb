# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import configs
import os
from scipy.stats import sem
import matplotlib.cm as cm
# Out:
# <frozen importlib._bootstrap>:219: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject

# %%
plt.rcParams['font.family'] = 'sans-serif'

# %% [markdown]
# # Testing 4 Room

# %%
#from deer.environments.FourRoom import MyEnv as Env
from deer.environments.Figure8 import MyEnv as Env

# %%
x = Env(higher_dim_obs=True, show_rewards=False, give_rewards=True)

# %%
m = x.observe()[0]

# %%
# %matplotlib notebook
plt.figure()
plt.imshow(m + np.random.normal(0,0.5, size=m.shape))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
plt.figure()
plt.imshow(m + np.random.normal(0,0.2, size=m.shape))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
m
# Out:
# array([[ 2.,  2.,  2.,  2.,  2.,  2.],
#        [ 2.,  0.,  0.,  0.,  0.,  2.],
#        [ 2.,  0., -1., -1.,  0.,  2.],
#        [ 2., 10.,  0.,  0.,  0.,  2.],
#        [ 2.,  0., -1., -1.,  0.,  2.],
#        [ 2.,  0.,  0.,  0.,  0.,  2.],
#        [ 2.,  2.,  2.,  2.,  2.,  2.]])
