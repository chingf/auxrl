# %%
import sys
import logging
import pickle
import yaml
from joblib import Parallel, delayed
import numpy as np
import matplotlib.pyplot as plt
from joblib import hash, dump, load
import os

from deer.default_parser import process_args
from deer.agent import NeuralAgent
from deer.learning_algos.CRAR_torch import CRAR
from catcher_alt1 import MyEnv as catcher_env
import deer.experiment.base_controllers as bc

from deer.policies import EpsilonGreedyPolicy

# %%
nn_yaml = 'network_simpler.yaml'
internal_dim = 10
fname = 'catcher_alt_visualization'
set_network = None #['foraging_mb', 30, True]

# %%
parameters = {
    'nn_yaml': nn_yaml,
    'higher_dim_obs': True,
    'internal_dim': internal_dim,
    'fname': fname,
    'steps_per_epoch': 1000,
    'epochs': 40,
    'steps_per_test': 1000,
    'period_btw_summary_perfs': 1,
    'encoder_type': 'regular',
    'frame_skip': 2,
    'learning_rate': 1*1E-4,
    'learning_rate_decay': 1.0,
    'discount': 0.9,
    'epsilon_start': 1.0,
    'epsilon_min': 1.0,
    'epsilon_decay': 1000,
    'update_frequency': 1,
    'replay_memory_size': 100000, #50000
    'batch_size': 64,
    'freeze_interval': 1000,
    'deterministic': False,
    #'loss_weights': [0, 1E-3, 1E-3, 0, 0, 1E-2, 1., 0],
    'loss_weights': [0, 0, 0, 0, 0, 0, 1., 0.],
    #'loss_weights': [1E-2, 1E-3, 1E-3, 0, 0, 1E-2, 1., 0],
    }

# %%
# --- Instantiate environment ---
rng = np.random.RandomState()
env = catcher_env(
    rng, higher_dim_obs=parameters['higher_dim_obs'], reverse=False
    )

# Algorithm
learning_algo = CRAR(
    env, parameters['freeze_interval'], parameters['batch_size'], rng,
    high_int_dim=False, internal_dim=parameters['internal_dim'],
    lr=parameters['learning_rate'], nn_yaml=parameters['nn_yaml'],
    double_Q=True, loss_weights=parameters['loss_weights'],
    encoder_type=parameters['encoder_type']
    )

# Policies
train_policy = EpsilonGreedyPolicy(learning_algo, env.nActions(), rng, 0.2)
test_policy = EpsilonGreedyPolicy(learning_algo, env.nActions(), rng, 0.)

# Initialize Agent
agent = NeuralAgent(
    env, learning_algo, parameters['replay_memory_size'], 1,
    parameters['batch_size'], rng,
    train_policy=train_policy, test_policy=test_policy)
if set_network is not None:
    agent.setNetwork(
        f'{set_network[0]}/fname', nEpoch=set_network[1],
        encoder_only=set_network[2]
        )
agent.run(10, 500)

# Attach controllers
agent.attach(bc.VerboseController( evaluate_on='epoch', periodicity=1))
agent.attach(bc.LearningRateController(
    initial_learning_rate=parameters['learning_rate'],
    learning_rate_decay=parameters['learning_rate_decay'],
    periodicity=1))
agent.attach(bc.TrainerController(
    evaluate_on='action', periodicity=parameters['update_frequency'],
    show_episode_avg_V_value=True, show_avg_Bellman_residual=True))
best_controller = bc.FindBestController(
    validationID=catcher_env.VALIDATION_MODE,
    testID=None, unique_fname=fname, savefrequency=5)
agent.attach(best_controller)
agent.attach(bc.InterleavedTestEpochController(
    id=catcher_env.VALIDATION_MODE, epoch_length=parameters['steps_per_test'],
    periodicity=1, show_score=True, summarize_every=1, unique_fname=fname))

# %%
if set_network is not None:
    agent.setNetwork(
        f'{set_network[0]}/fname', nEpoch=set_network[1],
        encoder_only=set_network[2]
        )
agent.run(parameters['epochs'], parameters['steps_per_epoch'])
# Out:
# Printing a few elements useful for debugging:
# actions_val[0], rewards_val[0], terminals_val[0]
# 1 1.0 False
# Es[0], TEs[0], Esp_[0]
# tensor([-0.1178, -0.0972, -0.0590,  0.0703, -0.0267], device='cuda:0') tensor([ 0.0433, -0.0537,  0.2479, -0.0130, -0.3698], device='cuda:0') tensor([-0.1242, -0.0983, -0.0592,  0.0676, -0.0309], device='cuda:0')
# R[0]
# tensor([0.2437], device='cuda:0', grad_fn=<SelectBackward0>)
# Average (on the epoch) training loss: 0.8748687323596742
# Episode average V value: -0.0493636354804039
# Average (on the epoch) training loss: 0.5492462767633023
# Episode average V value: 0.26382434243957203
# Average (on the epoch) training loss: 0.4101694753063307
# Episode average V value: 0.6669745763142904
# Average (on the epoch) training loss: 0.3730430276247493
# Episode average V value: 0.6534247795740763
# Average (on the epoch) training loss: 0.34594091266349314
# Episode average V value: 0.7006344199180603
# Average (on the epoch) training loss: 0.2443654533398811
# Episode average V value: 0.6332491407884615
# Average (on the epoch) training loss: 0.2200724232576111
# Episode average V value: 0.6343325444243171
# Average (on the epoch) training loss: 0.2153543738914127
# Episode average V value: 0.8374503254890442
# Average (on the epoch) training loss: 0.21158931076489454
# Episode average V value: 0.7563366625044081
# Average (on the epoch) training loss: 0.20169551255201285
# Episode average V value: 0.7087564858106467
# Average (on the epoch) training loss: 0.1991577863077647
# Episode average V value: 0.7207847908139229
# Average (on the epoch) training loss: 0.18967504251163014
# Episode average V value: 0.5632991688592094
# LOSSES
# T = 0.12511377013102173; R = 0.3016801900267601;                 Gamma = 1.6509241037368774; Q = 0.17511445554438979;
# Entropy Neighbor = 0.9481275408267975;                 Entropy Random = 0.9151330174207687;                 Volume = 11.648440418809653; VAE = 0.0
# Printing a few elements useful for debugging:
# actions_val[0], rewards_val[0], terminals_val[0]
# 0 1.0 False
# Es[0], TEs[0], Esp_[0]
# tensor([ 2.4363, -2.8489, -3.8943, -3.4306,  3.0019], device='cuda:0') tensor([ 2.4202, -3.5266, -4.3827, -3.8259,  3.1623], device='cuda:0') tensor([ 2.4401, -2.8685, -3.9060, -3.4368,  3.0056], device='cuda:0')
# R[0]
# tensor([0.6113], device='cuda:0', grad_fn=<SelectBackward0>)
# Average (on the epoch) training loss: 0.170302661726344
# Episode average V value: 0.6418562372525533
# Average (on the epoch) training loss: 0.16885131782468007
# Episode average V value: 0.5220543965697289
# Average (on the epoch) training loss: 0.16744196301938413
# Episode average V value: 0.7314697280526161
# Average (on the epoch) training loss: 0.15442265915662337
# Episode average V value: 0.6871359172001691
# Average (on the epoch) training loss: 0.14995460281469053
# Episode average V value: 0.6426353403500148
# Average (on the epoch) training loss: 0.1464525788611974
# Episode average V value: 0.5840246589095505
# Average (on the epoch) training loss: 0.1387181463632658
# Episode average V value: 0.668280428647995
# Average (on the epoch) training loss: 0.1357868834259109
# Episode average V value: 0.6892457329309903
# Average (on the epoch) training loss: 0.13305647076484114
# Episode average V value: 0.6554701345307486
# Average (on the epoch) training loss: 0.1325573239613936
# Episode average V value: 0.6200621591673957
# Average (on the epoch) training loss: 0.1321852090463418
# Episode average V value: 0.7621447642644247
# Average (on the epoch) training loss: 0.13068719081587243
# Episode average V value: 0.6967538330290053
# Average (on the epoch) training loss: 0.12887767886685342
# Episode average V value: 0.614649013236717
# Average (on the epoch) training loss: 0.12232780711924506
# Episode average V value: 0.742217418588238
# Average (on the epoch) training loss: 0.12087517941740453
# Episode average V value: 0.6555220484733582
# Average (on the epoch) training loss: 0.12031732284486252
# Episode average V value: 0.524664216571384
# Average (on the epoch) training loss: 0.11967586955970454
# Episode average V value: 0.49866487830877304
# LOSSES
# T = 0.1756588794887066; R = 0.2480868927538395;                 Gamma = 1.876573370218277; Q = 0.06273766408418305;
# Entropy Neighbor = 0.6731662685275078;                 Entropy Random = 0.5436186265945434;                 Volume = 14.643526941299438; VAE = 0.0
# Average (on the epoch) training loss: 0.11892605981428642
# Episode average V value: 0.878632128238678
# epoch 1:
# Learning rate: 0.0001
# Discount factor: 0.9
# Epsilon: 0.2
# /home/cf2794/.conda/envs/auxrl/lib/python3.8/site-packages/torch/optim/lr_scheduler.py:131: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn("Detected call of `lr_scheduler.step()` before `optimizer.step()`. "
# Testing score per episode (id: 0) is 56.94117647058823 (average over 17 episode(s))
# == Mean score per episode is 56.940841524461625 over 17 episodes ==
# /share/ctn/users/cf2794/Code/deer/examples/test_CRAR/catcher_alt1.py:113: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:204.)
#   all_possib_inp = torch.tensor(all_possib_inp).to(
# /share/ctn/users/cf2794/Code/deer/examples/test_CRAR/catcher_alt1.py:185: UserWarning: You passed a edgecolor/edgecolors ('k') for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   line3 = ax.scatter(
# Printing a few elements useful for debugging:
# actions_val[0], rewards_val[0], terminals_val[0]
# 1 1.0 False
# Es[0], TEs[0], Esp_[0]
# tensor([ 2.5803, -2.5766, -4.1864, -2.9682,  2.7995], device='cuda:0') tensor([ 2.6224, -3.3087, -4.4470, -3.2275,  2.8384], device='cuda:0') tensor([ 2.5533, -2.5643, -4.1505, -3.0191,  2.8766], device='cuda:0')
# R[0]
# tensor([0.5208], device='cuda:0', grad_fn=<SelectBackward0>)
# Average (on the epoch) training loss: 0.1511114974024618
# Episode average V value: 1.3802483456915822
# Average (on the epoch) training loss: 0.1507889698278011
# Episode average V value: 0.9063082635402679
# Average (on the epoch) training loss: 0.15077124652797702
# Episode average V value: 1.5236965815226238
# Average (on the epoch) training loss: 0.14126676067071794
# Episode average V value: 1.4246818047982674
# Average (on the epoch) training loss: 0.13178707152308727
# Episode average V value: 1.541938258541955
# Average (on the epoch) training loss: 0.12045188923366368
# Episode average V value: 1.2887852961017239
# Average (on the epoch) training loss: 0.1185557206445891
# Episode average V value: 1.56039293607076
# Average (on the epoch) training loss: 0.11436497461095098
# Episode average V value: 1.4852455177090385
# Average (on the epoch) training loss: 0.11246015774889452
# Episode average V value: 1.4418722482827993
# Average (on the epoch) training loss: 0.11177000472930053
# Episode average V value: 1.4413984343409538
# Average (on the epoch) training loss: 0.1074563363607237
# Episode average V value: 1.5111424724260967
# Average (on the epoch) training loss: 0.10665950162734404
# Episode average V value: 1.4375173648198445
# Average (on the epoch) training loss: 0.10600568138967856
# Episode average V value: 1.3923563890986972
# LOSSES
# T = 0.6795267371237278; R = 0.11520677602291107;                 Gamma = 3.4257680516242983; Q = 0.10295592704275623;
# Entropy Neighbor = 0.36092692068219184;                 Entropy Random = 0.2526999686807394;                 Volume = 52.17937195968628; VAE = 0.0
# Printing a few elements useful for debugging:
# actions_val[0], rewards_val[0], terminals_val[0]
# 1 1.0 False
# Es[0], TEs[0], Esp_[0]
# tensor([ 4.8926, -4.9756, -8.0363, -4.0541,  4.3843], device='cuda:0') tensor([ 5.0932, -6.3415, -8.6595, -4.4097,  4.7467], device='cuda:0') tensor([ 4.9199, -4.9352, -8.1194, -4.1015,  4.4514], device='cuda:0')
# R[0]
# tensor([0.7645], device='cuda:0', grad_fn=<SelectBackward0>)
# Average (on the epoch) training loss: 0.10172660705870752
# Episode average V value: 1.3501101769506931
# Average (on the epoch) training loss: 0.09455697351706581
# Episode average V value: 1.3576999149824445
# Average (on the epoch) training loss: 0.09244275778733749
# Episode average V value: 1.2524165792285271
# Average (on the epoch) training loss: 0.0893944331168555
# Episode average V value: 1.5391990298198328
# Average (on the epoch) training loss: 0.0878384050437652
# Episode average V value: 1.3406633443302578
# Average (on the epoch) training loss: 0.08751081361080962
# Episode average V value: 1.417529410786099
# Average (on the epoch) training loss: 0.0865963493476551
# Episode average V value: 1.4758113883435726
# Average (on the epoch) training loss: 0.08148393413555254
# Episode average V value: 1.391436890215802
# LOSSES
# T = 0.7640271475315094; R = 0.13619176472723485;                 Gamma = 3.060764886379242; Q = 0.05911723104864359;
# Entropy Neighbor = 0.25640794277191165;                 Entropy Random = 0.17699619245529175;                 Volume = 54.01735260772705; VAE = 0.0
# Average (on the epoch) training loss: 0.08103657904569991
# Episode average V value: 1.5948481678962707
# epoch 2:
# Learning rate: 0.0001
# Discount factor: 0.9
# Epsilon: 0.2
# Testing score per episode (id: 0) is 81.5 (average over 12 episode(s))
# == Mean score per episode is 81.49932083899301 over 12 episodes ==
# /share/ctn/users/cf2794/Code/deer/examples/test_CRAR/catcher_alt1.py:185: UserWarning: You passed a edgecolor/edgecolors ('k') for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   line3 = ax.scatter(
# Printing a few elements useful for debugging:
# actions_val[0], rewards_val[0], terminals_val[0]
# 1 1.0 False
# Es[0], TEs[0], Esp_[0]
# tensor([ 4.3789, -3.7510, -7.6055, -2.9377,  4.7484], device='cuda:0') tensor([ 4.4133, -4.8626, -7.9995, -3.1570,  4.9256], device='cuda:0') tensor([ 4.3873, -3.9156, -7.6445, -3.1215,  4.8661], device='cuda:0')
# R[0]
# tensor([0.6574], device='cuda:0', grad_fn=<SelectBackward0>)
# Average (on the epoch) training loss: 0.09218464644027898
# Episode average V value: 2.0913320187456117
# Average (on the epoch) training loss: 0.08050757661875751
# Episode average V value: 2.0914311075494405
# Average (on the epoch) training loss: 0.07826403032103375
# Episode average V value: 1.9919844998253717
# Average (on the epoch) training loss: 0.07337039252212108
# Episode average V value: 1.9439384679735443
# Average (on the epoch) training loss: 0.07323036117084099
# Episode average V value: 1.9091845378279686
# Average (on the epoch) training loss: 0.0733988507738526
# Episode average V value: 2.189736197976505
# Average (on the epoch) training loss: 0.0726508230668346
# Episode average V value: 1.4238541143781998
# Average (on the epoch) training loss: 0.07088669884776154
# Episode average V value: 1.7783156653245291
# Average (on the epoch) training loss: 0.07078772673825498
# Episode average V value: 1.979603992568122
# LOSSES
# T = 1.2228109060525894; R = 0.08221864869445562;                 Gamma = 3.7338725247383118; Q = 0.07064726163120941;
# Entropy Neighbor = 0.21197454303503035;                 Entropy Random = 0.13498142930865287;                 Volume = 95.74152489471436; VAE = 0.0
# Printing a few elements useful for debugging:
# actions_val[0], rewards_val[0], terminals_val[0]
# 1 1.0 False
# Es[0], TEs[0], Esp_[0]
# tensor([  6.3958,  -4.2489, -10.2159,  -3.1794,   6.7772], device='cuda:0') tensor([  6.2642,  -5.6511, -10.8465,  -3.3428,   6.9806], device='cuda:0') tensor([  6.4172,  -4.3859, -10.1205,  -3.5879,   7.0960], device='cuda:0')
# R[0]
# tensor([0.7532], device='cuda:0', grad_fn=<SelectBackward0>)
# Average (on the epoch) training loss: 0.07010729399961278
# Episode average V value: 2.113282163034786
# Average (on the epoch) training loss: 0.06786577355433357
# Episode average V value: 2.0097960678653584
# Average (on the epoch) training loss: 0.06826088471690983
# Episode average V value: 2.0300617482927112
# Average (on the epoch) training loss: 0.06818370019250782
# Episode average V value: 2.6212001144886017
# Average (on the epoch) training loss: 0.06823775635498948
# Episode average V value: 1.6028887041740947
# Average (on the epoch) training loss: 0.06837757739091391
# Episode average V value: 1.8747595595935034
# Average (on the epoch) training loss: 0.06842153871251656
# Episode average V value: 2.199097024069892
# Average (on the epoch) training loss: 0.06810151096751015
# Episode average V value: 1.9825203128986888
# Average (on the epoch) training loss: 0.06797854456208292
# Episode average V value: 2.13263487595099
# Average (on the epoch) training loss: 0.06780721725706287
# Episode average V value: 2.577472001314163
# Average (on the epoch) training loss: 0.06842732305517923
# Episode average V value: 2.0029702326830696
# Average (on the epoch) training loss: 0.06817677574166031
# Episode average V value: 2.356408178806305
# LOSSES
# T = 1.287887778401375; R = 0.09008292353898287;                 Gamma = 3.6297118797302246; Q = 0.06640016623865813;
# Entropy Neighbor = 0.18600971214473247;                 Entropy Random = 0.11494707148522139;                 Volume = 98.61623725891113; VAE = 0.0
# Average (on the epoch) training loss: 0.06852371393493377
# Episode average V value: 2.7065231800079346
# epoch 3:
# Learning rate: 0.0001
# Discount factor: 0.9
# Epsilon: 0.2
# Testing score per episode (id: 0) is 60.625 (average over 16 episode(s))
# == Mean score per episode is 60.62462109611815 over 16 episodes ==
# /share/ctn/users/cf2794/Code/deer/examples/test_CRAR/catcher_alt1.py:185: UserWarning: You passed a edgecolor/edgecolors ('k') for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   line3 = ax.scatter(
# Printing a few elements useful for debugging:
# actions_val[0], rewards_val[0], terminals_val[0]
# 1 1.0 False
# Es[0], TEs[0], Esp_[0]
# tensor([  6.3496,  -4.0072, -10.3281,  -3.2054,   7.0978], device='cuda:0') tensor([  6.1213,  -5.3829, -10.9596,  -3.3575,   7.2641], device='cuda:0') tensor([  6.6043,  -3.7719, -10.4408,  -2.5297,   6.7118], device='cuda:0')
# R[0]
# tensor([0.7439], device='cuda:0', grad_fn=<SelectBackward0>)
# Average (on the epoch) training loss: 0.15374282797399377
# Episode average V value: 2.690810549643732
# Average (on the epoch) training loss: 0.14990506992778843
# Episode average V value: 3.009810656309128
# Average (on the epoch) training loss: 0.14371287010859674
# Episode average V value: 2.909778846634759
# Average (on the epoch) training loss: 0.13758421780634128
# Episode average V value: 2.2264340586132474
# Average (on the epoch) training loss: 0.1318079262578653
# Episode average V value: 2.450073812367781
# Average (on the epoch) training loss: 0.13056571079362342
# Episode average V value: 3.033069542476109
# Average (on the epoch) training loss: 0.13005153804653444
# Episode average V value: 3.2773095220327377
# Average (on the epoch) training loss: 0.13236951551951426
# Episode average V value: 2.521450102329254
# Average (on the epoch) training loss: 0.1281585786574273
# Episode average V value: 2.8790176331050814
# Average (on the epoch) training loss: 0.12643211115694916
# Episode average V value: 2.492280848324299
# Average (on the epoch) training loss: 0.12628958817151464
# Episode average V value: 2.5601316849390665
# Average (on the epoch) training loss: 0.1270701086975874
# Episode average V value: 2.545489341020584
# Average (on the epoch) training loss: 0.12740655255741282
# Episode average V value: 2.730052908261617
# Average (on the epoch) training loss: 0.12754220806527883
# Episode average V value: 2.5904994010925293
# Average (on the epoch) training loss: 0.12781451431537452
# Episode average V value: 2.5425515174865723
# Average (on the epoch) training loss: 0.12953704587571943
# Episode average V value: 3.25892174243927
# Average (on the epoch) training loss: 0.12857236051941928
# Episode average V value: 2.5647980044869816
# LOSSES
# T = 1.7872564442157746; R = 0.059442142639309165;                 Gamma = 4.459922493934632; Q = 0.127106748462189;
# Entropy Neighbor = 0.17571674774587154;                 Entropy Random = 0.09433887447416782;                 Volume = 144.4056961212158; VAE = 0.0
# Printing a few elements useful for debugging:
# actions_val[0], rewards_val[0], terminals_val[0]
# 1 1.0 False
# Es[0], TEs[0], Esp_[0]
# tensor([  8.1136,  -5.5356, -12.5517,  -4.3570,   9.1549], device='cuda:0') tensor([  7.8776,  -7.2986, -13.5342,  -4.6277,   9.5375], device='cuda:0') tensor([  8.0502,  -5.3400, -12.4235,  -4.4004,   9.2778], device='cuda:0')
# R[0]
# tensor([0.9239], device='cuda:0', grad_fn=<SelectBackward0>)
# Average (on the epoch) training loss: 0.1263194373070539
# Episode average V value: 2.7490573724110923
# Average (on the epoch) training loss: 0.1252423743252461
# Episode average V value: 2.744211631662705
# Average (on the epoch) training loss: 0.1249063748587876
# Episode average V value: 2.8192902265056485
# Average (on the epoch) training loss: 0.1277601192164936
# Episode average V value: 2.702034832939269
# Average (on the epoch) training loss: 0.12756793468321587
# Episode average V value: 2.7537857514840587
# Average (on the epoch) training loss: 0.12651096224912065
# Episode average V value: 2.5365171876403836
# LOSSES
# T = 1.9132579805850982; R = 0.06220870194584131;                 Gamma = 4.5003042974472045; Q = 0.12496107974136249;
# Entropy Neighbor = 0.15261814314126967;                 Entropy Random = 0.07333791186288;                 Volume = 146.86415469360352; VAE = 0.0
# Average (on the epoch) training loss: 0.12603391410177572
# Episode average V value: 2.4828015879580847
# epoch 4:
# Learning rate: 0.0001
# Discount factor: 0.9
# Epsilon: 0.2
# Testing score per episode (id: 0) is 69.57142857142857 (average over 14 episode(s))
# == Mean score per episode is 69.5709316362026 over 14 episodes ==
# /share/ctn/users/cf2794/Code/deer/examples/test_CRAR/catcher_alt1.py:185: UserWarning: You passed a edgecolor/edgecolors ('k') for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   line3 = ax.scatter(
# Printing a few elements useful for debugging:
# actions_val[0], rewards_val[0], terminals_val[0]
# 1 1.0 False
# Es[0], TEs[0], Esp_[0]
# tensor([ 4.1948, -1.0175, -6.6751, -2.3176,  6.9256], device='cuda:0') tensor([ 3.4244, -1.6478, -7.0777, -2.3877,  6.6872], device='cuda:0') tensor([ 1.6882,  3.0610, -2.6371, -5.0417,  9.9370], device='cuda:0')
# R[0]
# tensor([0.4896], device='cuda:0', grad_fn=<SelectBackward0>)
# Average (on the epoch) training loss: 0.2150255514392888
# Episode average V value: 3.027025451193323
# Average (on the epoch) training loss: 0.21243987724891092
# Episode average V value: 2.89698788523674
# Average (on the epoch) training loss: 0.20111671653004332
# Episode average V value: 3.3436451256275177
# Average (on the epoch) training loss: 0.19631026322810502
# Episode average V value: 3.325793981552124
# Average (on the epoch) training loss: 0.1918802832170493
# Episode average V value: 2.3368162280983396
# Average (on the epoch) training loss: 0.18455876360980536
# Episode average V value: 3.0875946382681527
# Average (on the epoch) training loss: 0.18454348765137948
# Episode average V value: 2.850520624054803
# Average (on the epoch) training loss: 0.18085360672063153
# Episode average V value: 2.9661381021142006
# Average (on the epoch) training loss: 0.18278337501911351
# Episode average V value: 3.0673726167943745
# LOSSES
# T = 2.4979755527973175; R = 0.059397565593943;                 Gamma = 5.172729689598084; Q = 0.18198579485435037;
# Entropy Neighbor = 0.11447516787052155;                 Entropy Random = 0.0554831103477627;                 Volume = 191.8612033691406; VAE = 0.0
# Printing a few elements useful for debugging:
# actions_val[0], rewards_val[0], terminals_val[0]
# 1 1.0 False
# Es[0], TEs[0], Esp_[0]
# tensor([  9.5582,  -5.7946, -14.3297,  -4.7671,  10.5941], device='cuda:0') tensor([  9.1740,  -7.7757, -15.5102,  -5.0040,  10.9779], device='cuda:0') tensor([  9.8402,  -6.3172, -14.7200,  -3.7341,   9.5727], device='cuda:0')
# R[0]
# tensor([0.9917], device='cuda:0', grad_fn=<SelectBackward0>)
# Average (on the epoch) training loss: 0.17683655669073536
# Episode average V value: 3.145756020174398
# Average (on the epoch) training loss: 0.16864493568557212
# Episode average V value: 3.4332213977000094
# Average (on the epoch) training loss: 0.16914138811709428
# Episode average V value: 2.9209589461485543
# Average (on the epoch) training loss: 0.16910894287761016
# Episode average V value: 3.0202335092756485
# Average (on the epoch) training loss: 0.16840862018682376
# Episode average V value: 2.7412189978819628
# LOSSES
# T = 2.660301703453064; R = 0.05688232063548639;                 Gamma = 5.1977109518051146; Q = 0.15383211641060188;
# Entropy Neighbor = 0.09212360394746065;                 Entropy Random = 0.04877502068690956;                 Volume = 193.84907760620118; VAE = 0.0
# Average (on the epoch) training loss: 0.16790895563247613
# Episode average V value: 3.2454202336780096
# epoch 5:
# Learning rate: 0.0001
# Discount factor: 0.9
# Epsilon: 0.2
# Testing score per episode (id: 0) is 81.5 (average over 12 episode(s))
# == Mean score per episode is 81.49932083899301 over 12 episodes ==
# /share/ctn/users/cf2794/Code/deer/examples/test_CRAR/catcher_alt1.py:185: UserWarning: You passed a edgecolor/edgecolors ('k') for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   line3 = ax.scatter(
# Printing a few elements useful for debugging:
# actions_val[0], rewards_val[0], terminals_val[0]
# 0 1.0 False
# Es[0], TEs[0], Esp_[0]
# tensor([  9.5509,  -5.8750, -14.5908,  -4.3098,  10.1448], device='cuda:0') tensor([  9.1836,  -7.8013, -15.8587,  -4.5620,  10.5977], device='cuda:0') tensor([  9.3609,  -6.6704, -14.3451,  -3.6910,   8.8716], device='cuda:0')
# R[0]
# tensor([1.0506], device='cuda:0', grad_fn=<SelectBackward0>)
# Average (on the epoch) training loss: 0.23757303874640737
# Episode average V value: 3.4236914237833913
# Average (on the epoch) training loss: 0.22983437744463145
# Episode average V value: 3.1982608051861035
# Average (on the epoch) training loss: 0.2324342637457737
# Episode average V value: 3.4899111000391154
# Average (on the epoch) training loss: 0.22773840424062333
# Episode average V value: 3.2338082641363144
# Average (on the epoch) training loss: 0.21829300268938015
# Episode average V value: 3.5262491519634542
# Average (on the epoch) training loss: 0.22246001049267364
# Episode average V value: 3.380070759325611
# Average (on the epoch) training loss: 0.21955820849498756
# Episode average V value: 3.426671819554435
# Average (on the epoch) training loss: 0.21822995293811234
# Episode average V value: 3.463444047504001
# Average (on the epoch) training loss: 0.2165202868820773
# Episode average V value: 3.4834124225157277
# LOSSES
# T = 3.288932755470276; R = 0.06918444641306996;                 Gamma = 5.848726221084595; Q = 0.21440117696719244;
# Entropy Neighbor = 0.09178805716335774;                 Entropy Random = 0.042769862556830046;                 Volume = 238.49918283081055; VAE = 0.0
# Printing a few elements useful for debugging:
# actions_val[0], rewards_val[0], terminals_val[0]
# 0 1.0 False
# Es[0], TEs[0], Esp_[0]
# tensor([ 6.2247, -6.1305, -9.7550, -3.2762,  5.8557], device='cuda:0') tensor([  6.3318,  -7.5219, -10.7074,  -3.7203,   6.4618], device='cuda:0') tensor([ 4.7243, -6.0362, -7.9863, -2.3594,  3.7792], device='cuda:0')
# R[0]
# tensor([0.9251], device='cuda:0', grad_fn=<SelectBackward0>)
# Average (on the epoch) training loss: 0.21369496715996075
# Episode average V value: 3.172167953517702
# Average (on the epoch) training loss: 0.2106920078572096
# Episode average V value: 3.6997397343317666
# Average (on the epoch) training loss: 0.209136994894318
# Episode average V value: 3.406038072374132
# Average (on the epoch) training loss: 0.20973380859491922
# Episode average V value: 4.370566725730896
# Average (on the epoch) training loss: 0.2112178475844098
# Episode average V value: 3.1296763700597428
# Average (on the epoch) training loss: 0.2100242653612072
# Episode average V value: 3.769474425013103
# Average (on the epoch) training loss: 0.20812781307067957
# Episode average V value: 3.7180824279785156
# Average (on the epoch) training loss: 0.20973519834451157
# Episode average V value: 3.4365692532287455
# Average (on the epoch) training loss: 0.2113863542231314
# Episode average V value: 3.6765919556984534
# LOSSES
# T = 3.4115656495094298; R = 0.06638065343722702;                 Gamma = 5.850665644645691; Q = 0.20360620849439875;
# Entropy Neighbor = 0.10044778003543615;                 Entropy Random = 0.041571017207577825;                 Volume = 240.82689294433592; VAE = 0.0
# Average (on the epoch) training loss: 0.20900369273079558
# Episode average V value: 3.880100801255968
# epoch 6:
# Learning rate: 0.0001
# Discount factor: 0.9
# Epsilon: 0.2
# Testing score per episode (id: 0) is 109.33333333333333 (average over 9 episode(s))
# == Mean score per episode is 109.33211853201631 over 9 episodes ==
# /share/ctn/users/cf2794/Code/deer/examples/test_CRAR/catcher_alt1.py:185: UserWarning: You passed a edgecolor/edgecolors ('k') for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   line3 = ax.scatter(
# Printing a few elements useful for debugging:
# actions_val[0], rewards_val[0], terminals_val[0]
# 0 1.0 False
# Es[0], TEs[0], Esp_[0]
# tensor([ 10.9561,  -5.7108, -16.1002,  -5.9038,  12.6651], device='cuda:0') tensor([ 10.2942,  -7.8975, -17.6460,  -6.1683,  13.0540], device='cuda:0') tensor([ 10.6700,  -5.7685, -16.1180,  -5.6927,  12.4736], device='cuda:0')
# R[0]
# tensor([1.1351], device='cuda:0', grad_fn=<SelectBackward0>)
# Average (on the epoch) training loss: 0.3232913783027066
# Episode average V value: 4.086699485778809
# Average (on the epoch) training loss: 0.28088307266293594
# Episode average V value: 4.037967711440788
# Average (on the epoch) training loss: 0.2772340527105068
# Episode average V value: 4.236168059209983
# Average (on the epoch) training loss: 0.2722359336816371
# Episode average V value: 3.968914376364814
# LOSSES
# T = 4.009849801063537; R = 0.08751579604297877;                 Gamma = 6.426933100700379; Q = 0.2637532703652978;
# Entropy Neighbor = 0.09416596455872059;                 Entropy Random = 0.03737633697129786;                 Volume = 285.11937783813477; VAE = 0.0
# Printing a few elements useful for debugging:
# actions_val[0], rewards_val[0], terminals_val[0]
# 1 1.0 False
# Es[0], TEs[0], Esp_[0]
# tensor([ 12.3538,  -6.0108, -17.7060,  -6.5951,  14.3019], device='cuda:0') tensor([ 11.5710,  -8.4757, -19.3363,  -6.8052,  14.6420], device='cuda:0') tensor([ 12.3572,  -6.1107, -17.8134,  -6.4909,  14.3300], device='cuda:0')
# R[0]
# tensor([1.1443], device='cuda:0', grad_fn=<SelectBackward0>)
# Average (on the epoch) training loss: 0.26036314137472966
# Episode average V value: 3.74281127136668
# Average (on the epoch) training loss: 0.2591171321758058
# Episode average V value: 4.181959667967425
# Average (on the epoch) training loss: 0.25927317795087246
# Episode average V value: 3.084132353464762
# Average (on the epoch) training loss: 0.25652323058991
# Episode average V value: 4.171446738618143
# Average (on the epoch) training loss: 0.2537148774000574
# Episode average V value: 4.179538919812157
# Average (on the epoch) training loss: 0.25405799895357173
# Episode average V value: 3.5819411277770996
# LOSSES
# T = 4.046398245811463; R = 0.08254153998568654;                 Gamma = 6.366484815597534; Q = 0.24389652693457903;
# Entropy Neighbor = 0.08691442551463842;                 Entropy Random = 0.033827164170332255;                 Volume = 286.69660723876956; VAE = 0.0
# Average (on the epoch) training loss: 0.2538248986499384
# Episode average V value: 5.131560325622559
# epoch 7:
# Learning rate: 0.0001
# Discount factor: 0.9
# Epsilon: 0.2
# Testing score per episode (id: 0) is 69.57142857142857 (average over 14 episode(s))
# == Mean score per episode is 69.5709316362026 over 14 episodes ==
# /share/ctn/users/cf2794/Code/deer/examples/test_CRAR/catcher_alt1.py:185: UserWarning: You passed a edgecolor/edgecolors ('k') for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   line3 = ax.scatter(
# Printing a few elements useful for debugging:
# actions_val[0], rewards_val[0], terminals_val[0]
# 0 1.0 False
# Es[0], TEs[0], Esp_[0]
# tensor([ 11.9701, -10.6363, -17.8722,  -4.7977,   9.6207], device='cuda:0') tensor([ 12.2569, -13.2594, -19.6588,  -5.3478,  10.8030], device='cuda:0') tensor([ 11.6682, -10.4320, -17.3695,  -4.6013,   9.2068], device='cuda:0')
# R[0]
# tensor([1.3925], device='cuda:0', grad_fn=<SelectBackward0>)
# Average (on the epoch) training loss: 0.3169086427284927
# Episode average V value: 4.337156944173985
# Average (on the epoch) training loss: 0.31167632820843544
# Episode average V value: 4.184911268728751
# Average (on the epoch) training loss: 0.27764215625374933
# Episode average V value: 4.3685473512102675
# Average (on the epoch) training loss: 0.27810460474698784
# Episode average V value: 3.8891083547047205
# LOSSES
# T = 4.641799545288086; R = 0.10858112467825412;                 Gamma = 6.9153154163360595; Q = 0.27596777659188954;
# Entropy Neighbor = 0.07587210533022881;                 Entropy Random = 0.026559381432831288;                 Volume = 326.1372523193359; VAE = 0.0
# Printing a few elements useful for debugging:
# actions_val[0], rewards_val[0], terminals_val[0]
# 1 1.0 False
# Es[0], TEs[0], Esp_[0]
# tensor([  9.0234,  -9.8697, -13.6064,  -4.3849,   7.1269], device='cuda:0') tensor([  9.4775, -12.0174, -14.9837,  -5.0116,   8.2224], device='cuda:0') tensor([  7.9964, -10.4525, -12.6803,  -4.3399,   6.0426], device='cuda:0')
# R[0]
# tensor([1.1807], device='cuda:0', grad_fn=<SelectBackward0>)
# Average (on the epoch) training loss: 0.2780417193472685
# Episode average V value: 4.1512513234065125
# Average (on the epoch) training loss: 0.2776613768581892
# Episode average V value: 3.988173186779022
# Average (on the epoch) training loss: 0.27920364559800537
# Episode average V value: 4.060047405522044
# Average (on the epoch) training loss: 0.2777311944578805
# Episode average V value: 3.9878342572380516
# Average (on the epoch) training loss: 0.27537673069711993
# Episode average V value: 4.479691116346253
# Average (on the epoch) training loss: 0.2768699046768883
# Episode average V value: 4.1090220964473225
# Average (on the epoch) training loss: 0.2787233210045588
# Episode average V value: 3.9693445878870346
# Average (on the epoch) training loss: 0.27509690642432133
# Episode average V value: 4.243603673848239
# LOSSES
# T = 4.727787537097931; R = 0.10611096580326557;                 Gamma = 6.874881671905517; Q = 0.2742205321090296;
# Entropy Neighbor = 0.06711492475494743;                 Entropy Random = 0.02180574058764614;                 Volume = 327.34002642822264; VAE = 0.0
# Average (on the epoch) training loss: 0.2750941543504596
# Episode average V value: 5.809902286529541
# epoch 8:
# Learning rate: 0.0001
# Discount factor: 0.9
# Epsilon: 0.2
# Testing score per episode (id: 0) is 332.0 (average over 3 episode(s))
# == Mean score per episode is 331.9889337022099 over 3 episodes ==
# /share/ctn/users/cf2794/Code/deer/examples/test_CRAR/catcher_alt1.py:185: UserWarning: You passed a edgecolor/edgecolors ('k') for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   line3 = ax.scatter(
# Printing a few elements useful for debugging:
# actions_val[0], rewards_val[0], terminals_val[0]
# 1 1.0 False
# Es[0], TEs[0], Esp_[0]
# tensor([ 12.9703, -10.4293, -19.2654,  -5.2650,  11.3843], device='cuda:0') tensor([ 13.1191, -13.2608, -20.9977,  -5.7089,  12.4408], device='cuda:0') tensor([ 12.7126,  -7.8470, -19.1974,  -5.9646,  13.4731], device='cuda:0')
# R[0]
# tensor([1.3624], device='cuda:0', grad_fn=<SelectBackward0>)
# Average (on the epoch) training loss: 0.42479110178020263
# Episode average V value: 5.099620145909927
# Average (on the epoch) training loss: 0.3134624688015654
# Episode average V value: 4.726148827631671
# Average (on the epoch) training loss: 0.3128702700264568
# Episode average V value: 5.202627976735433
# Average (on the epoch) training loss: 0.31264093047594305
# Episode average V value: 4.504567601062633
# Average (on the epoch) training loss: 0.3120513626474551
# Episode average V value: 4.713458403944969
# Average (on the epoch) training loss: 0.31125982728439805
# Episode average V value: 4.771016378963695
# LOSSES
# T = 5.264172881126404; R = 0.13735752262175083;                 Gamma = 7.458821393966675; Q = 0.31281656461022794;
# Entropy Neighbor = 0.0542380291596055;                 Entropy Random = 0.016834169566631318;                 Volume = 368.0041636962891; VAE = 0.0
# Printing a few elements useful for debugging:
# actions_val[0], rewards_val[0], terminals_val[0]
# 1 1.0 False
# Es[0], TEs[0], Esp_[0]
# tensor([ 13.7334, -12.9235, -20.2389,  -4.8979,  10.0166], device='cuda:0') tensor([ 14.2910, -15.9895, -22.1815,  -5.5004,  11.4714], device='cuda:0') tensor([ 13.6966, -13.6330, -20.2300,  -5.0057,   9.6552], device='cuda:0')
# R[0]
# tensor([1.5017], device='cuda:0', grad_fn=<SelectBackward0>)
# Average (on the epoch) training loss: 0.31032188675324585
# Episode average V value: 4.291231226038049
# Average (on the epoch) training loss: 0.3162884296299854
# Episode average V value: 1.9165096812778049
# Average (on the epoch) training loss: 0.31334787557588156
# Episode average V value: 4.16648111560128
# Average (on the epoch) training loss: 0.3094012962323096
# Episode average V value: 4.638742375596661
# Average (on the epoch) training loss: 0.3032303370243194
# Episode average V value: 5.057420864533842
# Average (on the epoch) training loss: 0.313798892001311
# Episode average V value: 4.8310646796494385
# Average (on the epoch) training loss: 0.3183246723189154
# Episode average V value: 3.9092348225509066
# LOSSES
# T = 5.416516485214234; R = 0.13851925548911095;                 Gamma = 7.372109168052673; Q = 0.3372894749455154;
# Entropy Neighbor = 0.047090935628861186;                 Entropy Random = 0.014831547189154663;                 Volume = 369.45177294921876; VAE = 0.0
# Average (on the epoch) training loss: 0.32505301977787165
# Episode average V value: 4.575853299349546
# epoch 9:
# Learning rate: 0.0001
# Discount factor: 0.9
# Epsilon: 0.2
# Testing score per episode (id: 0) is 332.0 (average over 3 episode(s))
# == Mean score per episode is 331.9889337022099 over 3 episodes ==
# /share/ctn/users/cf2794/Code/deer/examples/test_CRAR/catcher_alt1.py:185: UserWarning: You passed a edgecolor/edgecolors ('k') for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   line3 = ax.scatter(
# Printing a few elements useful for debugging:
# actions_val[0], rewards_val[0], terminals_val[0]
# 1 1.0 False
# Es[0], TEs[0], Esp_[0]
# tensor([ 14.7019,  -5.6621, -19.9810,  -7.0657,  16.4938], device='cuda:0') tensor([ 13.5878,  -8.3771, -21.9037,  -7.1528,  16.7064], device='cuda:0') tensor([ 14.6730,  -5.5273, -19.9105,  -6.8867,  16.2498], device='cuda:0')
# R[0]
# tensor([1.1936], device='cuda:0', grad_fn=<SelectBackward0>)
# Average (on the epoch) training loss: 0.36134231329346317
# Episode average V value: 4.640556608509813
# KeyboardInterrupt

# %% [markdown]
# # Visualize performance

# %%
agent.setNetwork(f'{fname}/fname', nEpoch=5)

# %%
fdir = 'transfer_catcher_simpler_dim10_pt9'
fname = 'transfer_catcher_mf_4'
agent.setNetwork(f'{fdir}/{fname}/fname', nEpoch=50)

# %%
agent._in_episode = True
agent._mode = 0 # Testing mode with plan_depth=0
initState = env.reset(agent._mode)
inputDims = env.inputDimensions()

for i in range(len(inputDims)):
    if inputDims[i][0] > 1:
        agent._state[i][1:] = initState[i][1:]
agent._Vs_on_last_episode = []
is_terminal = False
reward = 0

# %%
# %matplotlib inline
height = (env._height + 2)*3
width = (env._width + 2)*3
frames = []
for i in range(100):
    obs = env.observe()
    _obs = obs[0]
    plt.figure()
    frame = np.flip(_obs.squeeze())
    plt.imshow(frame)
    frames.append(frame)
    plt.show()
    if is_terminal: break
    for i in range(len(obs)):
        agent._state[i][0:-1] = agent._state[i][1:]
        agent._state[i][-1] = obs[i]
    V, action, reward, _ = agent._step()
    print(action)
    agent._Vs_on_last_episode.append(V)
    is_terminal = env.inTerminalState()
# Out:
# tensor(1, device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(1, device='cuda:0')

# %%
# %matplotlib notebook

import numpy as np 
import matplotlib.pyplot as plt
from IPython.display import HTML
import matplotlib.animation as animation

fig, ax = plt.subplots(1,1)
ax.set_xticks([])
ax.set_yticks([])
im = ax.imshow(np.zeros((height, width)))

def init():
    plt.cla()
    im = ax.imshow(_obs)
    return [im]

def animate(i, *args, **kwargs):
    plt.cla()
    im = ax.imshow(frames[i])
#     obs = env.observe()
#     _obs = obs[0].reshape((env.WIDTH, env.HEIGHT))
#     _obs = np.flip(_obs.squeeze())
#     im = ax.imshow(_obs)
#     for i in range(len(obs)):
#         agent._state[i][0:-1] = agent._state[i][1:]
#         agent._state[i][-1] = obs[i]
#         V, action, reward, _ = agent._step()
#         agent._Vs_on_last_episode.append(V)
    return [im]

ani = animation.FuncAnimation(fig, animate, init_func=init, 
     frames=len(frames), blit=False, repeat=True)
ani.save(f'figs/catcher_alt.gif', writer="ffmpeg", fps = 30)
fig.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# MovieWriter ffmpeg unavailable; using Pillow instead.
